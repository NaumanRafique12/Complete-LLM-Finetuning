# %% [markdown]
# GPTQ = original algorithm/paper (ETH Zurich, 2022).
#
# AutoGPTQ = practical Python library (Hugging Face maintained) that made GPTQ mainstream and easy to use.
#
# https://github.com/AutoGPTQ/AutoGPTQ

# %% [markdown]
# | Feature / Library       | **AutoGPTQ**                          | **bitsandbytes**                                      | **gptqmodel**                                                  |
# | ----------------------- | ------------------------------------- | ----------------------------------------------------- | -------------------------------------------------------------- |
# | **Origin**              | Hugging Face ecosystem (2023)         | Tim Dettmers (2022)                                   | ModelCloud (2024–2025)                                         |
# | **Quantization Method** | GPTQ (post-training, 4/8-bit)         | Linear quantization (INT8, NF4, FP4, 8-bit optimizer) | GPTQ v1, GPTQ v2, QQQ, EoRA, GAR                               |
# | **Target Use**          | Easy Hugging Face integration         | Training & inference memory savings                   | **Full production deployment toolkit**                         |
# | **Hardware Support**    | CUDA (Nvidia GPU)                     | CUDA (Nvidia GPU) only                                | CUDA (Nvidia), ROCm (AMD), XPU (Intel), MPS (Apple), CPU       |
# | **Integration**         | Hugging Face Transformers             | PyTorch Optimizer + HF integration                    | HF Transformers, vLLM, SGLang, Optimum, Peft                   |
# | **Inference Kernels**   | ExLlama, Triton, Marlin (via plugins) | cuBLAS-based INT8 kernels                             | Marlin, ExLlama v2, Torch fused, BitBLAS                       |
# | **Training Support**    | No                                    | Optimizer states (8-bit Adam, NF4 LoRA)             | Partial (LoRA + EoRA fine-tune on quantized model)             |
# | **Flexibility**         | Focused on GPTQ only                  | Training + inference memory efficiency                | **Dynamic per-layer configs, adapters, GAR, eval integration** |
# | **Evaluation**          | None built-in                         | None built-in                                         | Built-in `lm-eval` & `evalplus` hooks                          |
# | **Ease of Use**         | Very easy (HF-style API)            | Very easy (drop-in optimizer / load\_in\_8bit=True) | More advanced config, but still has high-level API             |
# | **Community Models**    | Huge (TheBloke, HF Hub)               | Many LoRA + finetune models                           | Growing rapidly (ModelCloud & HF Hub vortex/EoRA releases)     |
# | **Strengths**           | Easy Hugging Face usage               | Simple + effective for training                       | All-in-one production toolkit, multi-hardware                  |
# | **Weaknesses**          | Limited to GPTQ only                  | Nvidia-only, no GPTQ                                  | More complex, newer ecosystem (still maturing)                 |

# %% [markdown]
# Versions & Techniques
#
# GPTQ v1, GPTQ v2 → GPTQ ke alag implementations / improvements
#
# QQQ → Quick Quantization for Transformers (speed optimized variant)
#
# EoRA → Efficient Online Row-wise Approximation (better per-row error handling)
#
# GAR → Gradient Aware Rounding (quantization ke liye advanced rounding strategy)

# %% [markdown]
# https://github.com/ModelCloud/GPTQModel

# %% [markdown]
# pip install gptqmodel → install the gptqmodel package.
#
# -v → verbose mode, so pip prints more details about what it is doing (downloads, builds, etc.).
#
# --no-build-isolation → disables pip’s default build isolation behavior when installing from source (sdist). It means pip will not create an isolated environment to build dependencies; you’re responsible to have all build dependencies present already.

# %%
# !pip install -v gptqmodel --no-build-isolation
# Out:
# Using pip 24.1.2 from /usr/local/lib/python3.12/dist-packages/pip (python 3.12)
# Collecting gptqmodel
#   Downloading gptqmodel-4.2.5.tar.gz (331 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.7/331.7 kB 5.8 MB/s eta 0:00:00
#   Running command Preparing metadata (pyproject.toml)
#   CUDA_ARCH_LIST: 7.5
#   TORCH_CUDA_ARCH_LIST: 7.5
#   CUDA 7.5
#   HAS_CUDA_V8 False
#   SETUP_KWARGS {'ext_modules': [], 'cmdclass': {'build_ext': <class 'torch.utils.cpp_extension.BuildExtension'>}}
#   running dist_info
#   creating /tmp/pip-modern-metadata-2iuo6oj0/gptqmodel.egg-info
#   writing /tmp/pip-modern-metadata-2iuo6oj0/gptqmodel.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-modern-metadata-2iuo6oj0/gptqmodel.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-modern-metadata-2iuo6oj0/gptqmodel.egg-info/requires.txt
#   writing top-level names to /tmp/pip-modern-metadata-2iuo6oj0/gptqmodel.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-modern-metadata-2iuo6oj0/gptqmodel.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-modern-metadata-2iuo6oj0/gptqmodel.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   no previously-included directories found matching 'tests'
#   no previously-included directories found matching 'format'
#   adding license file 'LICENSE'
#   writing manifest file '/tmp/pip-modern-metadata-2iuo6oj0/gptqmodel.egg-info/SOURCES.txt'
#   creating '/tmp/pip-modern-metadata-2iuo6oj0/gptqmodel-4.2.5.dist-info'
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: accelerate>=1.10.1 in /usr/local/lib/python3.12/dist-packages (from gptqmodel) (1.10.1)
#   Link requires a different Python (3.12.11 not in: '>=3.7,<3.11'): https://files.pythonhosted.org/packages/3a/be/650f9c091ef71cb01d735775d554e068752d3ff63d7943b26316dc401749/numpy-1.21.2.zip (from https://pypi.org/simple/numpy/) (requires-python:>=3.7,<3.11)
#   Link requires a different Python (3.12.11 not in: '>=3.7,<3.11'): https://files.pythonhosted.org/packages/5f/d6/ad58ded26556eaeaa8c971e08b6466f17c4ac4d786cd3d800e26ce59cc01/numpy-1.21.3.zip (from https://pypi.org/simple/numpy/) (requires-python:>=3.7,<3.11)
#   Link requires a different Python (3.12.11 not in: '>=3.7,<3.11'): https://files.pythonhosted.org/packages/fb/48/b0708ebd7718a8933f0d3937513ef8ef2f4f04529f1f66ca86d873043921/numpy-1.21.4.zip (from https://pypi.org/simple/numpy/) (requires-python:>=3.7,<3.11)
#   Link requires a different Python (3.12.11 not in: '>=3.7,<3.11'): https://files.pythonhosted.org/packages/c2/a8/a924a09492bdfee8c2ec3094d0a13f2799800b4fdc9c890738aeeb12c72e/numpy-1.21.5.zip (from https://pypi.org/simple/numpy/) (requires-python:>=3.7,<3.11)
#   Link requires a different Python (3.12.11 not in: '>=3.7,<3.11'): https://files.pythonhosted.org/packages/45/b7/de7b8e67f2232c26af57c205aaad29fe17754f793404f59c8a730c7a191a/numpy-1.21.6.zip (from https://pypi.org/simple/numpy/) (requires-python:>=3.7,<3.11)
# Collecting numpy>=2.2.6 (from gptqmodel)
#   Obtaining dependency information for numpy>=2.2.6 from https://files.pythonhosted.org/packages/51/64/7de3c91e821a2debf77c92962ea3fe6ac2bc45d0778c1cbe15d4fce2fd94/numpy-2.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata
#   Downloading numpy-2.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: torch>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from gptqmodel) (2.8.0+cu126)
# Requirement already satisfied: safetensors>=0.6.2 in /usr/local/lib/python3.12/dist-packages (from gptqmodel) (0.6.2)
# Requirement already satisfied: transformers>=4.56.0 in /usr/local/lib/python3.12/dist-packages (from gptqmodel) (4.56.1)
# Requirement already satisfied: threadpoolctl>=3.6.0 in /usr/local/lib/python3.12/dist-packages (from gptqmodel) (3.6.0)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.12/dist-packages (from gptqmodel) (25.0)
# Collecting device-smi==0.4.1 (from gptqmodel)
#   Downloading device_smi-0.4.1.tar.gz (17 kB)
#   Running command python setup.py egg_info
#   /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/dist.py:261: UserWarning: Unknown distribution option: 'platform'
#     warnings.warn(msg)
#   running egg_info
#   creating /tmp/pip-pip-egg-info-u5ppjf5_/device_smi.egg-info
#   writing /tmp/pip-pip-egg-info-u5ppjf5_/device_smi.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-u5ppjf5_/device_smi.egg-info/dependency_links.txt
#   writing top-level names to /tmp/pip-pip-egg-info-u5ppjf5_/device_smi.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-u5ppjf5_/device_smi.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-u5ppjf5_/device_smi.egg-info/SOURCES.txt'
#   adding license file 'LICENSE'
#   writing manifest file '/tmp/pip-pip-egg-info-u5ppjf5_/device_smi.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Collecting protobuf>=6.32.0 (from gptqmodel)
#   Obtaining dependency information for protobuf>=6.32.0 from https://files.pythonhosted.org/packages/5c/f6/88d77011b605ef979aace37b7703e4eefad066f7e84d935e5a696515c2dd/protobuf-6.32.1-cp39-abi3-manylinux2014_x86_64.whl.metadata
#   Downloading protobuf-6.32.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Requirement already satisfied: pillow>=11.3.0 in /usr/local/lib/python3.12/dist-packages (from gptqmodel) (11.3.0)
# Requirement already satisfied: hf-transfer>=0.1.9 in /usr/local/lib/python3.12/dist-packages (from gptqmodel) (0.1.9)
# Requirement already satisfied: huggingface-hub>=0.34.4 in /usr/local/lib/python3.12/dist-packages (from gptqmodel) (0.35.0)
# Collecting random-word==1.0.13 (from gptqmodel)
#   Obtaining dependency information for random-word==1.0.13 from https://files.pythonhosted.org/packages/df/46/3ce7166b6f99e61fab286d807bf8834cb8e23adbc1becff047b37c9cd666/random_word-1.0.13-py3-none-any.whl.metadata
#   Downloading random_word-1.0.13-py3-none-any.whl.metadata (4.3 kB)
# Collecting tokenicer>=0.0.5 (from gptqmodel)
#   Downloading tokenicer-0.0.5.tar.gz (11 kB)
#   Running command python setup.py egg_info
#   /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/dist.py:261: UserWarning: Unknown distribution option: 'platform'
#     warnings.warn(msg)
#   running egg_info
#   creating /tmp/pip-pip-egg-info-40hpd8om/tokenicer.egg-info
#   writing /tmp/pip-pip-egg-info-40hpd8om/tokenicer.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-40hpd8om/tokenicer.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-40hpd8om/tokenicer.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-40hpd8om/tokenicer.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-40hpd8om/tokenicer.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-40hpd8om/tokenicer.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   no previously-included directories found matching 'tests'
#   adding license file 'LICENSE'
#   writing manifest file '/tmp/pip-pip-egg-info-40hpd8om/tokenicer.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Collecting logbar==0.0.4 (from gptqmodel)
#   Downloading logbar-0.0.4.tar.gz (12 kB)
#   Running command python setup.py egg_info
#   /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/dist.py:261: UserWarning: Unknown distribution option: 'platform'
#     warnings.warn(msg)
#   running egg_info
#   creating /tmp/pip-pip-egg-info-mvgnvdrw/logbar.egg-info
#   writing /tmp/pip-pip-egg-info-mvgnvdrw/logbar.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-mvgnvdrw/logbar.egg-info/dependency_links.txt
#   writing top-level names to /tmp/pip-pip-egg-info-mvgnvdrw/logbar.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-mvgnvdrw/logbar.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-mvgnvdrw/logbar.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   no previously-included directories found matching 'tests'
#   adding license file 'LICENSE'
#   writing manifest file '/tmp/pip-pip-egg-info-mvgnvdrw/logbar.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: wheel>=0.45.1 in /usr/local/lib/python3.12/dist-packages (from gptqmodel) (0.45.1)
# Collecting maturin>=1.9.3 (from gptqmodel)
#   Obtaining dependency information for maturin>=1.9.3 from https://files.pythonhosted.org/packages/d2/46/001fcc5c6ad509874896418d6169a61acd619df5b724f99766308c44a99f/maturin-1.9.4-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.musllinux_1_1_x86_64.whl.metadata
#   Downloading maturin-1.9.4-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.musllinux_1_1_x86_64.whl.metadata (16 kB)
# Collecting autopep8<3.0.0,>=2.3.1 (from random-word==1.0.13->gptqmodel)
#   Obtaining dependency information for autopep8<3.0.0,>=2.3.1 from https://files.pythonhosted.org/packages/9e/43/53afb8ba17218f19b77c7834128566c5bbb100a0ad9ba2e8e89d089d7079/autopep8-2.3.2-py2.py3-none-any.whl.metadata
#   Downloading autopep8-2.3.2-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: pytest<9.0.0,>=8.3.3 in /usr/local/lib/python3.12/dist-packages (from random-word==1.0.13->gptqmodel) (8.4.2)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.2 in /usr/local/lib/python3.12/dist-packages (from random-word==1.0.13->gptqmodel) (6.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.12/dist-packages (from random-word==1.0.13->gptqmodel) (2.32.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.10.1->gptqmodel) (5.9.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.34.4->gptqmodel) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.34.4->gptqmodel) (2025.3.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.34.4->gptqmodel) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.34.4->gptqmodel) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.34.4->gptqmodel) (1.1.10)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->gptqmodel) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->gptqmodel) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->gptqmodel) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->gptqmodel) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->gptqmodel) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->gptqmodel) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->gptqmodel) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->gptqmodel) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->gptqmodel) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->gptqmodel) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->gptqmodel) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->gptqmodel) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->gptqmodel) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->gptqmodel) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->gptqmodel) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->gptqmodel) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->gptqmodel) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->gptqmodel) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->gptqmodel) (3.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.56.0->gptqmodel) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.56.0->gptqmodel) (0.22.0)
# Collecting pycodestyle>=2.12.0 (from autopep8<3.0.0,>=2.3.1->random-word==1.0.13->gptqmodel)
#   Obtaining dependency information for pycodestyle>=2.12.0 from https://files.pythonhosted.org/packages/d7/27/a58ddaf8c588a3ef080db9d0b7e0b97215cee3a45df74f3a94dbbf5c893a/pycodestyle-2.14.0-py2.py3-none-any.whl.metadata
#   Downloading pycodestyle-2.14.0-py2.py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest<9.0.0,>=8.3.3->random-word==1.0.13->gptqmodel) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest<9.0.0,>=8.3.3->random-word==1.0.13->gptqmodel) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest<9.0.0,>=8.3.3->random-word==1.0.13->gptqmodel) (2.19.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->random-word==1.0.13->gptqmodel) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->random-word==1.0.13->gptqmodel) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->random-word==1.0.13->gptqmodel) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->random-word==1.0.13->gptqmodel) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.8.0->gptqmodel) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.8.0->gptqmodel) (3.0.2)
# Downloading random_word-1.0.13-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 47.4 MB/s eta 0:00:00
# Downloading maturin-1.9.4-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.musllinux_1_1_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 61.3 MB/s eta 0:00:00
# Downloading numpy-2.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 59.4 MB/s eta 0:00:00
# Downloading protobuf-6.32.1-cp39-abi3-manylinux2014_x86_64.whl (322 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.0/322.0 kB 25.4 MB/s eta 0:00:00
# Downloading autopep8-2.3.2-py2.py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 2.8 MB/s eta 0:00:00
# Downloading pycodestyle-2.14.0-py2.py3-none-any.whl (31 kB)
# Building wheels for collected packages: gptqmodel, device-smi, logbar, tokenicer
#   Running command Building wheel for gptqmodel (pyproject.toml)
#   CUDA_ARCH_LIST: 7.5
#   TORCH_CUDA_ARCH_LIST: 7.5
#   CUDA 7.5
#   HAS_CUDA_V8 False
#   SETUP_KWARGS {'ext_modules': [], 'cmdclass': {'build_ext': <class 'torch.utils.cpp_extension.BuildExtension'>}}
#   running bdist_wheel
#   W0924 10:38:16.729000 1255 torch/utils/cpp_extension.py:615] Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   Resolved wheel URL: https://github.com/ModelCloud/GPTQModel/releases/download/v4.2.5/gptqmodel-4.2.5+cu125torch2.8-cp312-cp312-linux_x86_64.whl
#   wheel name=gptqmodel-4.2.5+cu125torch2.8-cp312-cp312-linux_x86_64.whl
#   Precompiled wheel not found at: https://github.com/ModelCloud/GPTQModel/releases/download/v4.2.5/gptqmodel-4.2.5+cu125torch2.8-cp312-cp312-linux_x86_64.whl. Building from source...
#   running build
#   running build_py
#   creating build/lib/gptqmodel
#   copying gptqmodel/__init__.py -> build/lib/gptqmodel
#   copying gptqmodel/version.py -> build/lib/gptqmodel
#   creating build/lib/gptqmodel/adapter
#   copying gptqmodel/adapter/__init__.py -> build/lib/gptqmodel/adapter
#   copying gptqmodel/adapter/adapter.py -> build/lib/gptqmodel/adapter
#   copying gptqmodel/adapter/peft.py -> build/lib/gptqmodel/adapter
#   copying gptqmodel/adapter/remote.py -> build/lib/gptqmodel/adapter
#   creating build/lib/gptqmodel/eora
#   copying gptqmodel/eora/__init__.py -> build/lib/gptqmodel/eora
#   copying gptqmodel/eora/eora.py -> build/lib/gptqmodel/eora
#   creating build/lib/gptqmodel/quantization
#   copying gptqmodel/quantization/gptq.py -> build/lib/gptqmodel/quantization
#   copying gptqmodel/quantization/quantizer.py -> build/lib/gptqmodel/quantization
#   copying gptqmodel/quantization/config.py -> build/lib/gptqmodel/quantization
#   copying gptqmodel/quantization/__init__.py -> build/lib/gptqmodel/quantization
#   copying gptqmodel/quantization/gar.py -> build/lib/gptqmodel/quantization
#   copying gptqmodel/quantization/gptqv2.py -> build/lib/gptqmodel/quantization
#   copying gptqmodel/quantization/qqq.py -> build/lib/gptqmodel/quantization
#   creating build/lib/gptqmodel/looper
#   copying gptqmodel/looper/module_looper.py -> build/lib/gptqmodel/looper
#   copying gptqmodel/looper/__init__.py -> build/lib/gptqmodel/looper
#   copying gptqmodel/looper/named_module.py -> build/lib/gptqmodel/looper
#   copying gptqmodel/looper/loop_processor.py -> build/lib/gptqmodel/looper
#   copying gptqmodel/looper/input_cache.py -> build/lib/gptqmodel/looper
#   copying gptqmodel/looper/dequantize_processor.py -> build/lib/gptqmodel/looper
#   copying gptqmodel/looper/gptq_processor.py -> build/lib/gptqmodel/looper
#   copying gptqmodel/looper/eora_processor.py -> build/lib/gptqmodel/looper
#   copying gptqmodel/looper/qqq_processor.py -> build/lib/gptqmodel/looper
#   copying gptqmodel/looper/native_processor.py -> build/lib/gptqmodel/looper
#   creating build/lib/gptqmodel/models
#   copying gptqmodel/models/base.py -> build/lib/gptqmodel/models
#   copying gptqmodel/models/loader.py -> build/lib/gptqmodel/models
#   copying gptqmodel/models/__init__.py -> build/lib/gptqmodel/models
#   copying gptqmodel/models/writer.py -> build/lib/gptqmodel/models
#   copying gptqmodel/models/auto.py -> build/lib/gptqmodel/models
#   copying gptqmodel/models/_const.py -> build/lib/gptqmodel/models
#   creating build/lib/gptqmodel/nn_modules
#   copying gptqmodel/nn_modules/__init__.py -> build/lib/gptqmodel/nn_modules
#   copying gptqmodel/nn_modules/hooked_linear.py -> build/lib/gptqmodel/nn_modules
#   creating build/lib/gptqmodel/utils
#   copying gptqmodel/utils/safetensor.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/importer.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/evalplus.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/__init__.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/rocm.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/perplexity.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/mlx.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/plotly.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/device.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/calibration.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/marlin.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/logger.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/exllama.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/structure.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/hf.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/vram.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/openai_server.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/torch.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/eval.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/terminal.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/vllm.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/sglang.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/image.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/tensor.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/backend.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/model.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/bitblas.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/data.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/mmlupro.py -> build/lib/gptqmodel/utils
#   copying gptqmodel/utils/python.py -> build/lib/gptqmodel/utils
#   creating build/lib/gptqmodel/quantization/rotation
#   copying gptqmodel/quantization/rotation/hadamard_utils.py -> build/lib/gptqmodel/quantization/rotation
#   copying gptqmodel/quantization/rotation/__init__.py -> build/lib/gptqmodel/quantization/rotation
#   copying gptqmodel/quantization/rotation/rotation.py -> build/lib/gptqmodel/quantization/rotation
#   creating build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/gemma3.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/deepseek_v3.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/gpt_neox.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/qwen2_5_vl.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/moss.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/internlm2.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/llama4.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/kimi_k2.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/decilm.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/seed_oss.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/yi.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/qwen2.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/opt.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/dbrx_converted.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/xverse.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/longllama.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/qwen3.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/base_qwen2_vl.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/pangu_alpha.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/phi4.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/gptj.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/__init__.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/gemma2.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/ovis.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/rw.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/dream.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/deepseek_v2.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/phi3.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/qwen.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/falcon_h1.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/qwen3_next.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/mistral.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/mimo.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/phi.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/gpt2.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/telechat2.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/glm.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/internlm.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/llama.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/mpt.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/longcat_flash.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/mobilellm.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/instella.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/olmo2.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/stablelmepoch.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/gemma.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/ernie4_5_moe.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/chatglm.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/gpt_neo.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/granite.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/apertus.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/qwen2_vl.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/baichuan.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/gpt_oss.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/qwen2_5_omni.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/minicpm.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/codegen.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/qwen2_moe.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/starcoder2.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/glm4_moe.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/nemotron_h.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/dbrx.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/bloom.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/base_qwen2_5_omni.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/minicpm3.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/cohere.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/klear.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/cohere2.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/llava_qwen2.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/grinmoe.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/gpt_bigcode.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/hymba.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/mixtral.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/qwen3_moe.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/exaone.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/ernie4_5.py -> build/lib/gptqmodel/models/definitions
#   copying gptqmodel/models/definitions/mllama.py -> build/lib/gptqmodel/models/definitions
#   creating build/lib/gptqmodel/nn_modules/qlinear
#   copying gptqmodel/nn_modules/qlinear/tritonv2.py -> build/lib/gptqmodel/nn_modules/qlinear
#   copying gptqmodel/nn_modules/qlinear/__init__.py -> build/lib/gptqmodel/nn_modules/qlinear
#   copying gptqmodel/nn_modules/qlinear/bitblas_target_detector.py -> build/lib/gptqmodel/nn_modules/qlinear
#   copying gptqmodel/nn_modules/qlinear/marlin.py -> build/lib/gptqmodel/nn_modules/qlinear
#   copying gptqmodel/nn_modules/qlinear/exllama.py -> build/lib/gptqmodel/nn_modules/qlinear
#   copying gptqmodel/nn_modules/qlinear/ipex.py -> build/lib/gptqmodel/nn_modules/qlinear
#   copying gptqmodel/nn_modules/qlinear/utils.py -> build/lib/gptqmodel/nn_modules/qlinear
#   copying gptqmodel/nn_modules/qlinear/torch.py -> build/lib/gptqmodel/nn_modules/qlinear
#   copying gptqmodel/nn_modules/qlinear/exllamav2.py -> build/lib/gptqmodel/nn_modules/qlinear
#   copying gptqmodel/nn_modules/qlinear/qqq.py -> build/lib/gptqmodel/nn_modules/qlinear
#   copying gptqmodel/nn_modules/qlinear/bitblas.py -> build/lib/gptqmodel/nn_modules/qlinear
#   copying gptqmodel/nn_modules/qlinear/exllama_eora.py -> build/lib/gptqmodel/nn_modules/qlinear
#   copying gptqmodel/nn_modules/qlinear/torch_fused.py -> build/lib/gptqmodel/nn_modules/qlinear
#   creating build/lib/gptqmodel/nn_modules/triton_utils
#   copying gptqmodel/nn_modules/triton_utils/custom_autotune.py -> build/lib/gptqmodel/nn_modules/triton_utils
#   copying gptqmodel/nn_modules/triton_utils/kernels.py -> build/lib/gptqmodel/nn_modules/triton_utils
#   copying gptqmodel/nn_modules/triton_utils/__init__.py -> build/lib/gptqmodel/nn_modules/triton_utils
#   copying gptqmodel/nn_modules/triton_utils/mixin.py -> build/lib/gptqmodel/nn_modules/triton_utils
#   copying gptqmodel/nn_modules/triton_utils/dequant.py -> build/lib/gptqmodel/nn_modules/triton_utils
#   installing to build/bdist.linux-x86_64/wheel
#   running install
#   running install_lib
#   creating build/bdist.linux-x86_64/wheel
#   creating build/bdist.linux-x86_64/wheel/gptqmodel
#   creating build/bdist.linux-x86_64/wheel/gptqmodel/adapter
#   copying build/lib/gptqmodel/adapter/__init__.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/adapter
#   copying build/lib/gptqmodel/adapter/adapter.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/adapter
#   copying build/lib/gptqmodel/adapter/peft.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/adapter
#   copying build/lib/gptqmodel/adapter/remote.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/adapter
#   copying build/lib/gptqmodel/__init__.py -> build/bdist.linux-x86_64/wheel/./gptqmodel
#   creating build/bdist.linux-x86_64/wheel/gptqmodel/eora
#   copying build/lib/gptqmodel/eora/__init__.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/eora
#   copying build/lib/gptqmodel/eora/eora.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/eora
#   creating build/bdist.linux-x86_64/wheel/gptqmodel/quantization
#   copying build/lib/gptqmodel/quantization/gptq.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/quantization
#   copying build/lib/gptqmodel/quantization/quantizer.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/quantization
#   creating build/bdist.linux-x86_64/wheel/gptqmodel/quantization/rotation
#   copying build/lib/gptqmodel/quantization/rotation/hadamard_utils.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/quantization/rotation
#   copying build/lib/gptqmodel/quantization/rotation/__init__.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/quantization/rotation
#   copying build/lib/gptqmodel/quantization/rotation/rotation.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/quantization/rotation
#   copying build/lib/gptqmodel/quantization/config.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/quantization
#   copying build/lib/gptqmodel/quantization/__init__.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/quantization
#   copying build/lib/gptqmodel/quantization/gar.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/quantization
#   copying build/lib/gptqmodel/quantization/gptqv2.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/quantization
#   copying build/lib/gptqmodel/quantization/qqq.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/quantization
#   creating build/bdist.linux-x86_64/wheel/gptqmodel/looper
#   copying build/lib/gptqmodel/looper/module_looper.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/looper
#   copying build/lib/gptqmodel/looper/__init__.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/looper
#   copying build/lib/gptqmodel/looper/named_module.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/looper
#   copying build/lib/gptqmodel/looper/loop_processor.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/looper
#   copying build/lib/gptqmodel/looper/input_cache.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/looper
#   copying build/lib/gptqmodel/looper/dequantize_processor.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/looper
#   copying build/lib/gptqmodel/looper/gptq_processor.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/looper
#   copying build/lib/gptqmodel/looper/eora_processor.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/looper
#   copying build/lib/gptqmodel/looper/qqq_processor.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/looper
#   copying build/lib/gptqmodel/looper/native_processor.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/looper
#   creating build/bdist.linux-x86_64/wheel/gptqmodel/models
#   copying build/lib/gptqmodel/models/base.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models
#   copying build/lib/gptqmodel/models/loader.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models
#   copying build/lib/gptqmodel/models/__init__.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models
#   creating build/bdist.linux-x86_64/wheel/gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/gemma3.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/deepseek_v3.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/gpt_neox.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/qwen2_5_vl.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/moss.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/internlm2.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/llama4.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/kimi_k2.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/decilm.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/seed_oss.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/yi.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/qwen2.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/opt.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/dbrx_converted.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/xverse.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/longllama.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/qwen3.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/base_qwen2_vl.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/pangu_alpha.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/phi4.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/gptj.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/__init__.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/gemma2.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/ovis.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/rw.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/dream.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/deepseek_v2.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/phi3.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/qwen.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/falcon_h1.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/qwen3_next.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/mistral.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/mimo.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/phi.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/gpt2.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/telechat2.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/glm.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/internlm.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/llama.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/mpt.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/longcat_flash.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/mobilellm.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/instella.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/olmo2.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/stablelmepoch.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/gemma.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/ernie4_5_moe.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/chatglm.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/gpt_neo.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/granite.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/apertus.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/qwen2_vl.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/baichuan.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/gpt_oss.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/qwen2_5_omni.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/minicpm.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/codegen.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/qwen2_moe.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/starcoder2.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/glm4_moe.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/nemotron_h.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/dbrx.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/bloom.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/base_qwen2_5_omni.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/minicpm3.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/cohere.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/klear.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/cohere2.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/llava_qwen2.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/grinmoe.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/gpt_bigcode.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/hymba.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/mixtral.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/qwen3_moe.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/exaone.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/ernie4_5.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/definitions/mllama.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models/definitions
#   copying build/lib/gptqmodel/models/writer.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models
#   copying build/lib/gptqmodel/models/auto.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models
#   copying build/lib/gptqmodel/models/_const.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/models
#   creating build/bdist.linux-x86_64/wheel/gptqmodel/nn_modules
#   copying build/lib/gptqmodel/nn_modules/__init__.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/nn_modules
#   creating build/bdist.linux-x86_64/wheel/gptqmodel/nn_modules/qlinear
#   copying build/lib/gptqmodel/nn_modules/qlinear/tritonv2.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/nn_modules/qlinear
#   copying build/lib/gptqmodel/nn_modules/qlinear/__init__.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/nn_modules/qlinear
#   copying build/lib/gptqmodel/nn_modules/qlinear/bitblas_target_detector.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/nn_modules/qlinear
#   copying build/lib/gptqmodel/nn_modules/qlinear/marlin.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/nn_modules/qlinear
#   copying build/lib/gptqmodel/nn_modules/qlinear/exllama.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/nn_modules/qlinear
#   copying build/lib/gptqmodel/nn_modules/qlinear/ipex.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/nn_modules/qlinear
#   copying build/lib/gptqmodel/nn_modules/qlinear/utils.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/nn_modules/qlinear
#   copying build/lib/gptqmodel/nn_modules/qlinear/torch.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/nn_modules/qlinear
#   copying build/lib/gptqmodel/nn_modules/qlinear/exllamav2.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/nn_modules/qlinear
#   copying build/lib/gptqmodel/nn_modules/qlinear/qqq.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/nn_modules/qlinear
#   copying build/lib/gptqmodel/nn_modules/qlinear/bitblas.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/nn_modules/qlinear
#   copying build/lib/gptqmodel/nn_modules/qlinear/exllama_eora.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/nn_modules/qlinear
#   copying build/lib/gptqmodel/nn_modules/qlinear/torch_fused.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/nn_modules/qlinear
#   creating build/bdist.linux-x86_64/wheel/gptqmodel/nn_modules/triton_utils
#   copying build/lib/gptqmodel/nn_modules/triton_utils/custom_autotune.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/nn_modules/triton_utils
#   copying build/lib/gptqmodel/nn_modules/triton_utils/kernels.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/nn_modules/triton_utils
#   copying build/lib/gptqmodel/nn_modules/triton_utils/__init__.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/nn_modules/triton_utils
#   copying build/lib/gptqmodel/nn_modules/triton_utils/mixin.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/nn_modules/triton_utils
#   copying build/lib/gptqmodel/nn_modules/triton_utils/dequant.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/nn_modules/triton_utils
#   copying build/lib/gptqmodel/nn_modules/hooked_linear.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/nn_modules
#   creating build/bdist.linux-x86_64/wheel/gptqmodel/utils
#   copying build/lib/gptqmodel/utils/safetensor.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/utils
#   copying build/lib/gptqmodel/utils/importer.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/utils
#   copying build/lib/gptqmodel/utils/evalplus.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/utils
#   copying build/lib/gptqmodel/utils/__init__.py -> build/bdist.linux-x86_64/wheel/./gptqmodel/utils
# ...
#   adding 'gptqmodel/nn_modules/qlinear/exllama_eora.py'
#   adding 'gptqmodel/nn_modules/qlinear/exllamav2.py'
#   adding 'gptqmodel/nn_modules/qlinear/ipex.py'
#   adding 'gptqmodel/nn_modules/qlinear/marlin.py'
#   adding 'gptqmodel/nn_modules/qlinear/qqq.py'
#   adding 'gptqmodel/nn_modules/qlinear/torch.py'
#   adding 'gptqmodel/nn_modules/qlinear/torch_fused.py'
#   adding 'gptqmodel/nn_modules/qlinear/tritonv2.py'
#   adding 'gptqmodel/nn_modules/qlinear/utils.py'
#   adding 'gptqmodel/nn_modules/triton_utils/__init__.py'
#   adding 'gptqmodel/nn_modules/triton_utils/custom_autotune.py'
#   adding 'gptqmodel/nn_modules/triton_utils/dequant.py'
#   adding 'gptqmodel/nn_modules/triton_utils/kernels.py'
#   adding 'gptqmodel/nn_modules/triton_utils/mixin.py'
#   adding 'gptqmodel/quantization/__init__.py'
#   adding 'gptqmodel/quantization/config.py'
#   adding 'gptqmodel/quantization/gar.py'
#   adding 'gptqmodel/quantization/gptq.py'
#   adding 'gptqmodel/quantization/gptqv2.py'
#   adding 'gptqmodel/quantization/qqq.py'
#   adding 'gptqmodel/quantization/quantizer.py'
#   adding 'gptqmodel/quantization/rotation/__init__.py'
#   adding 'gptqmodel/quantization/rotation/hadamard_utils.py'
#   adding 'gptqmodel/quantization/rotation/rotation.py'
#   adding 'gptqmodel/utils/__init__.py'
#   adding 'gptqmodel/utils/backend.py'
#   adding 'gptqmodel/utils/bitblas.py'
#   adding 'gptqmodel/utils/calibration.py'
#   adding 'gptqmodel/utils/data.py'
#   adding 'gptqmodel/utils/device.py'
#   adding 'gptqmodel/utils/eval.py'
#   adding 'gptqmodel/utils/evalplus.py'
#   adding 'gptqmodel/utils/exllama.py'
#   adding 'gptqmodel/utils/hf.py'
#   adding 'gptqmodel/utils/image.py'
#   adding 'gptqmodel/utils/importer.py'
#   adding 'gptqmodel/utils/logger.py'
#   adding 'gptqmodel/utils/marlin.py'
#   adding 'gptqmodel/utils/mlx.py'
#   adding 'gptqmodel/utils/mmlupro.py'
#   adding 'gptqmodel/utils/model.py'
#   adding 'gptqmodel/utils/openai_server.py'
#   adding 'gptqmodel/utils/perplexity.py'
#   adding 'gptqmodel/utils/plotly.py'
#   adding 'gptqmodel/utils/python.py'
#   adding 'gptqmodel/utils/rocm.py'
#   adding 'gptqmodel/utils/safetensor.py'
#   adding 'gptqmodel/utils/sglang.py'
#   adding 'gptqmodel/utils/structure.py'
#   adding 'gptqmodel/utils/tensor.py'
#   adding 'gptqmodel/utils/terminal.py'
#   adding 'gptqmodel/utils/torch.py'
#   adding 'gptqmodel/utils/vllm.py'
#   adding 'gptqmodel/utils/vram.py'
#   adding 'gptqmodel-4.2.5.dist-info/LICENSE'
#   adding 'gptqmodel-4.2.5.dist-info/METADATA'
#   adding 'gptqmodel-4.2.5.dist-info/WHEEL'
#   adding 'gptqmodel-4.2.5.dist-info/top_level.txt'
#   adding 'gptqmodel-4.2.5.dist-info/RECORD'
#   removing build/bdist.linux-x86_64/wheel
#   Building wheel for gptqmodel (pyproject.toml) ... done
#   Created wheel for gptqmodel: filename=gptqmodel-4.2.5-py3-none-any.whl size=335002 sha256=090b75fe6892ff871734ea3b4b4afc90b26fdcfb0a1a9a5e1efd69661202511a
#   Stored in directory: /root/.cache/pip/wheels/55/ff/71/4ab173b87e5dce071613d4a6d033258ffcc7bf17991cc8bc66
#   Running command python setup.py bdist_wheel
#   /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/dist.py:261: UserWarning: Unknown distribution option: 'platform'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build/lib/device_smi
#   copying device_smi/base.py -> build/lib/device_smi
#   copying device_smi/amd.py -> build/lib/device_smi
#   copying device_smi/__init__.py -> build/lib/device_smi
#   copying device_smi/os.py -> build/lib/device_smi
#   copying device_smi/device.py -> build/lib/device_smi
#   copying device_smi/nvidia.py -> build/lib/device_smi
#   copying device_smi/intel.py -> build/lib/device_smi
#   copying device_smi/apple.py -> build/lib/device_smi
#   copying device_smi/cpu.py -> build/lib/device_smi
#   /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
#   !!
#
#           ********************************************************************************
#           Please avoid running ``setup.py`` directly.
#           Instead, use pypa/build, pypa/installer or other
#           standards-based tools.
#
#           See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#           ********************************************************************************
#
#   !!
#     self.initialize_options()
#   installing to build/bdist.linux-x86_64/wheel
#   running install
#   running install_lib
#   creating build/bdist.linux-x86_64/wheel
#   creating build/bdist.linux-x86_64/wheel/device_smi
#   copying build/lib/device_smi/base.py -> build/bdist.linux-x86_64/wheel/./device_smi
#   copying build/lib/device_smi/amd.py -> build/bdist.linux-x86_64/wheel/./device_smi
#   copying build/lib/device_smi/__init__.py -> build/bdist.linux-x86_64/wheel/./device_smi
#   copying build/lib/device_smi/os.py -> build/bdist.linux-x86_64/wheel/./device_smi
#   copying build/lib/device_smi/device.py -> build/bdist.linux-x86_64/wheel/./device_smi
#   copying build/lib/device_smi/nvidia.py -> build/bdist.linux-x86_64/wheel/./device_smi
#   copying build/lib/device_smi/intel.py -> build/bdist.linux-x86_64/wheel/./device_smi
#   copying build/lib/device_smi/apple.py -> build/bdist.linux-x86_64/wheel/./device_smi
#   copying build/lib/device_smi/cpu.py -> build/bdist.linux-x86_64/wheel/./device_smi
#   running install_egg_info
#   running egg_info
#   writing device_smi.egg-info/PKG-INFO
#   writing dependency_links to device_smi.egg-info/dependency_links.txt
#   writing top-level names to device_smi.egg-info/top_level.txt
#   reading manifest file 'device_smi.egg-info/SOURCES.txt'
#   adding license file 'LICENSE'
#   writing manifest file 'device_smi.egg-info/SOURCES.txt'
#   Copying device_smi.egg-info to build/bdist.linux-x86_64/wheel/./device_smi-0.4.1-py3.12.egg-info
#   running install_scripts
#   creating build/bdist.linux-x86_64/wheel/device_smi-0.4.1.dist-info/WHEEL
#   creating '/tmp/pip-wheel-0slrcv6_/device_smi-0.4.1-py3-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
#   adding 'device_smi/__init__.py'
#   adding 'device_smi/amd.py'
#   adding 'device_smi/apple.py'
#   adding 'device_smi/base.py'
#   adding 'device_smi/cpu.py'
#   adding 'device_smi/device.py'
#   adding 'device_smi/intel.py'
#   adding 'device_smi/nvidia.py'
#   adding 'device_smi/os.py'
#   adding 'device_smi-0.4.1.dist-info/LICENSE'
#   adding 'device_smi-0.4.1.dist-info/METADATA'
#   adding 'device_smi-0.4.1.dist-info/WHEEL'
#   adding 'device_smi-0.4.1.dist-info/top_level.txt'
#   adding 'device_smi-0.4.1.dist-info/RECORD'
#   removing build/bdist.linux-x86_64/wheel
#   Building wheel for device-smi (setup.py) ... done
#   Created wheel for device-smi: filename=device_smi-0.4.1-py3-none-any.whl size=17886 sha256=e38bcbc81d265bfe0a124c86fc0df7d89de24f073016c2b788b69cafffd01406
#   Stored in directory: /root/.cache/pip/wheels/78/92/be/62e3dbb42c5dff06ed29453b0fd9bf17179c5a5add89ca6cbd
#   Running command python setup.py bdist_wheel
#   /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/dist.py:261: UserWarning: Unknown distribution option: 'platform'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build/lib/logbar
#   copying logbar/logbar.py -> build/lib/logbar
#   copying logbar/util.py -> build/lib/logbar
#   copying logbar/__init__.py -> build/lib/logbar
#   copying logbar/progress.py -> build/lib/logbar
#   copying logbar/terminal.py -> build/lib/logbar
#   /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
#   !!
#
#           ********************************************************************************
#           Please avoid running ``setup.py`` directly.
#           Instead, use pypa/build, pypa/installer or other
#           standards-based tools.
#
#           See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#           ********************************************************************************
#
#   !!
#     self.initialize_options()
#   installing to build/bdist.linux-x86_64/wheel
#   running install
#   running install_lib
#   creating build/bdist.linux-x86_64/wheel
#   creating build/bdist.linux-x86_64/wheel/logbar
#   copying build/lib/logbar/logbar.py -> build/bdist.linux-x86_64/wheel/./logbar
#   copying build/lib/logbar/util.py -> build/bdist.linux-x86_64/wheel/./logbar
#   copying build/lib/logbar/__init__.py -> build/bdist.linux-x86_64/wheel/./logbar
#   copying build/lib/logbar/progress.py -> build/bdist.linux-x86_64/wheel/./logbar
#   copying build/lib/logbar/terminal.py -> build/bdist.linux-x86_64/wheel/./logbar
#   running install_egg_info
#   running egg_info
#   writing logbar.egg-info/PKG-INFO
#   writing dependency_links to logbar.egg-info/dependency_links.txt
#   writing top-level names to logbar.egg-info/top_level.txt
#   reading manifest file 'logbar.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   no previously-included directories found matching 'tests'
#   adding license file 'LICENSE'
#   writing manifest file 'logbar.egg-info/SOURCES.txt'
#   Copying logbar.egg-info to build/bdist.linux-x86_64/wheel/./logbar-0.0.4-py3.12.egg-info
#   running install_scripts
#   creating build/bdist.linux-x86_64/wheel/logbar-0.0.4.dist-info/WHEEL
#   creating '/tmp/pip-wheel-kickxikn/logbar-0.0.4-py3-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
#   adding 'logbar/__init__.py'
#   adding 'logbar/logbar.py'
#   adding 'logbar/progress.py'
#   adding 'logbar/terminal.py'
#   adding 'logbar/util.py'
#   adding 'logbar-0.0.4.dist-info/LICENSE'
#   adding 'logbar-0.0.4.dist-info/METADATA'
#   adding 'logbar-0.0.4.dist-info/WHEEL'
#   adding 'logbar-0.0.4.dist-info/top_level.txt'
#   adding 'logbar-0.0.4.dist-info/RECORD'
#   removing build/bdist.linux-x86_64/wheel
#   Building wheel for logbar (setup.py) ... done
#   Created wheel for logbar: filename=logbar-0.0.4-py3-none-any.whl size=12635 sha256=c74ef8c90ec94b2edb4e6fbbca3e88d1556ca41a4913e0cbffacb2b5cae780f6
#   Stored in directory: /root/.cache/pip/wheels/f9/f2/88/c815d0365e734e5f55bbf798723463bf17472ab984b92e4ee0
#   Running command python setup.py bdist_wheel
#   /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/dist.py:261: UserWarning: Unknown distribution option: 'platform'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build/lib/tokenicer
#   copying tokenicer/tokenicer.py -> build/lib/tokenicer
#   copying tokenicer/util.py -> build/lib/tokenicer
#   copying tokenicer/__init__.py -> build/lib/tokenicer
#   copying tokenicer/const.py -> build/lib/tokenicer
#   /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
#   !!
#
#           ********************************************************************************
#           Please avoid running ``setup.py`` directly.
#           Instead, use pypa/build, pypa/installer or other
#           standards-based tools.
#
#           See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#           ********************************************************************************
#
#   !!
#     self.initialize_options()
#   installing to build/bdist.linux-x86_64/wheel
#   running install
#   running install_lib
#   creating build/bdist.linux-x86_64/wheel
#   creating build/bdist.linux-x86_64/wheel/tokenicer
#   copying build/lib/tokenicer/tokenicer.py -> build/bdist.linux-x86_64/wheel/./tokenicer
#   copying build/lib/tokenicer/util.py -> build/bdist.linux-x86_64/wheel/./tokenicer
#   copying build/lib/tokenicer/__init__.py -> build/bdist.linux-x86_64/wheel/./tokenicer
#   copying build/lib/tokenicer/const.py -> build/bdist.linux-x86_64/wheel/./tokenicer
#   running install_egg_info
#   running egg_info
#   writing tokenicer.egg-info/PKG-INFO
#   writing dependency_links to tokenicer.egg-info/dependency_links.txt
#   writing requirements to tokenicer.egg-info/requires.txt
#   writing top-level names to tokenicer.egg-info/top_level.txt
#   reading manifest file 'tokenicer.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   no previously-included directories found matching 'tests'
#   adding license file 'LICENSE'
#   writing manifest file 'tokenicer.egg-info/SOURCES.txt'
#   Copying tokenicer.egg-info to build/bdist.linux-x86_64/wheel/./tokenicer-0.0.5-py3.12.egg-info
#   running install_scripts
#   creating build/bdist.linux-x86_64/wheel/tokenicer-0.0.5.dist-info/WHEEL
#   creating '/tmp/pip-wheel-ctjb77bv/tokenicer-0.0.5-py3-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
#   adding 'tokenicer/__init__.py'
#   adding 'tokenicer/const.py'
#   adding 'tokenicer/tokenicer.py'
#   adding 'tokenicer/util.py'
#   adding 'tokenicer-0.0.5.dist-info/LICENSE'
#   adding 'tokenicer-0.0.5.dist-info/METADATA'
#   adding 'tokenicer-0.0.5.dist-info/WHEEL'
#   adding 'tokenicer-0.0.5.dist-info/top_level.txt'
#   adding 'tokenicer-0.0.5.dist-info/RECORD'
#   removing build/bdist.linux-x86_64/wheel
#   Building wheel for tokenicer (setup.py) ... done
#   Created wheel for tokenicer: filename=tokenicer-0.0.5-py3-none-any.whl size=11547 sha256=86627bbd20be7928a06768dbf5aec8d1c6b0f6d5993f09b8e15696e798184072
#   Stored in directory: /root/.cache/pip/wheels/30/9b/e5/de00363d221bc580d63c91131bea5aedea54830457a9690cff
# Successfully built gptqmodel device-smi logbar tokenicer
# Installing collected packages: pycodestyle, protobuf, numpy, maturin, logbar, device-smi, autopep8, random-word, tokenicer, gptqmodel
#   changing mode of /usr/local/bin/pycodestyle to 755
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Removing file or directory /usr/local/lib/python3.12/dist-packages/google/_upb/
#       Removing file or directory /usr/local/lib/python3.12/dist-packages/google/protobuf/
#       Removing file or directory /usr/local/lib/python3.12/dist-packages/protobuf-5.29.5.dist-info/
#       Successfully uninstalled protobuf-5.29.5
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Removing file or directory /usr/local/bin/f2py
#       Removing file or directory /usr/local/bin/numpy-config
#       Removing file or directory /usr/local/lib/python3.12/dist-packages/numpy-2.0.2.dist-info/
#       Removing file or directory /usr/local/lib/python3.12/dist-packages/numpy.libs/
#       Removing file or directory /usr/local/lib/python3.12/dist-packages/numpy/
#       Successfully uninstalled numpy-2.0.2
#   changing mode of /usr/local/bin/f2py to 755
#   changing mode of /usr/local/bin/numpy-config to 755
#   changing mode of /usr/local/bin/autopep8 to 755
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.3 which is incompatible.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.32.1 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.3 which is incompatible.
# cupy-cuda12x 13.3.0 requires numpy<2.3,>=1.22, but you have numpy 2.3.3 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.3 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.3 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 6.32.1 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.3.3 which is incompatible.
# tensorflow 2.19.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.32.1 which is incompatible.
# Successfully installed autopep8-2.3.2 device-smi-0.4.1 gptqmodel-4.2.5 logbar-0.0.4 maturin-1.9.4 numpy-2.3.3 protobuf-6.32.1 pycodestyle-2.14.0 random-word-1.0.13 tokenicer-0.0.5

# %%
# !pip install "protobuf<6.30"
# Out:
# Requirement already satisfied: protobuf<6.30 in /usr/local/lib/python3.12/dist-packages (5.29.5)

# %%
from gptqmodel import GPTQModel
# Out:
# WARN  Python GIL is enabled: Multi-gpu quant acceleration for MoE models is sub-optimal and multi-core accelerated cpu packing is also disabled. We recommend Python >= 3.13.3t with Pytorch > 2.8 for mult-gpu quantization and multi-cpu packing with env `PYTHON_GIL=0`.
# WARN  Feature `utils/Perplexity` requires python GIL or Python >= 3.13.3T (T for Threading-Free edition of Python) plus Torch 2.8. Feature is currently skipped/disabled.
# INFO  ENV: Auto setting PYTORCH_CUDA_ALLOC_CONF='expandable_segments:True' for memory saving.
# INFO  ENV: Auto setting CUDA_DEVICE_ORDER=PCI_BUS_ID for correctness.

# %%
import gptqmodel
dir(gptqmodel)
# Out:
# ['BACKEND',
#  'BaseQuantizeConfig',
#  'GPTQModel',
#  'QuantizeConfig',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'adapter',
#  'exllama_set_max_input_length',
#  'get_best_device',
#  'looper',
#  'models',
#  'nn_modules',
#  'os',
#  'quantization',
#  'utils',
#  'version']

# %% [markdown]
# https://huggingface.co/collections/ModelCloud/vortex-673743382af0a52b2a8b9fe2

# %%
model = GPTQModel.load("ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# from_quantized: adapter: None
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# quantize_config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.61G [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# INFO  Loader: Auto dtype (native bfloat16): `torch.bfloat16`
# INFO  Estimated Quantization BPW (bits per weight): 4.85 bpw, based on [bits: 4, group_size: 32]
# `torch_dtype` is deprecated! Use `dtype` instead!
# INFO   Kernel: Auto-selection: adding candidate `TritonV2QuantLinear`
# INFO   Kernel: Auto-selection: adding candidate `TorchQuantLinear`
# INFO  Kernel: candidates -> `[TritonV2QuantLinear, TorchQuantLinear]`
# INFO  Kernel: selected -> `TritonV2QuantLinear`.
# WARNING:accelerate.utils.modeling:The model weights are not tied. Please use the `tie_weights` method before using the `infer_auto_device` function.
# INFO  Format: Converting `checkpoint_format` from `FORMAT.GPTQ` to internal `FORMAT.GPTQ_V2`.
# INFO  Format: Converting GPTQ v1 to v2
# INFO  Format: Conversion complete: 0.058113813400268555s
# INFO   Kernel: Auto-selection: adding candidate `TritonV2QuantLinear`
# INFO  Optimize: `TritonV2QuantLinear` compilation triggered.
# INFO  Model: Loaded `generation_config`: GenerationConfig {
#   "bos_token_id": 128000,
#   "eos_token_id": [
#     128001,
#     128008,
#     128009
#   ]
# }
#
# INFO  Model: `generation_config.json` not found. Skipped checking.
# INFO  Kernel: loaded -> `[TritonV2QuantLinear]`

# %%
result = model.generate("Uncovering deep insights begins with")[0] # tokens

# %%
print(model.tokenizer.decode(result)) # string output
# Out:
# <|begin_of_text|>Uncovering deep insights begins with a deep understanding of the underlying principles and concepts that govern the behavior of the system in question. In

# %% [markdown]
# <|begin_of_text|>Uncovering deep insights begins with a deep understanding of the underlying principles and concepts that govern the behavior of the system in question. In

# %%
model_id = "meta-llama/Llama-3.2-1B-Instruct"

# %%
quant_path = "Llama-3.2-1B-Instruct-gptqmodel-4bit"

# %%
from datasets import load_dataset
calibration_dataset = load_dataset(
    "allenai/c4",
    data_files="en/c4-train.00001-of-01024.json.gz",
    split="train"
  ).select(range(1024))["text"]

# %%
from gptqmodel import GPTQModel, QuantizeConfig

# %%
quant_config = QuantizeConfig(bits=4, group_size=128)

# %%
model = GPTQModel.load(model_id, quant_config)
# Out:
# config.json:   0%|          | 0.00/877 [00:00<?, ?B/s]
# INFO  Estimated Quantization BPW (bits per weight): 4.2875 bpw, based on [bits: 4, group_size: 128]
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# params.json:   0%|          | 0.00/220 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.47G [00:00<?, ?B/s]
# original/consolidated.00.pth:   0%|          | 0.00/2.47G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/41.7k [00:00<?, ?B/s]
# LICENSE.txt:   0%|          | 0.00/7.71k [00:00<?, ?B/s]
# original/tokenizer.model:   0%|          | 0.00/2.18M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/54.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# USE_POLICY.md:   0%|          | 0.00/6.02k [00:00<?, ?B/s]
# INFO  Loader: Auto dtype (native bfloat16): `torch.bfloat16`
# INFO  Model: Loaded `generation_config`: GenerationConfig {
#   "bos_token_id": 128000,
#   "do_sample": true,
#   "eos_token_id": [
#     128001,
#     128008,
#     128009
#   ],
#   "temperature": 0.6,
#   "top_p": 0.9
# }
#
# INFO  Kernel: loaded -> `[]`

# %% [markdown]
# QuantizeConfig Parameters Explained
#
# bits: int = 4
# Number of bits for quantization (2, 3, 4, 8). Lower bits = more compression, less accuracy.
#
# dynamic: Dict[...] | None
# Allows per-layer overrides. Example: quantize some layers with 8 bits, others skip quantization.
#
# group_size: int = 128
# Number of weights grouped together before quantization.
# Smaller = better accuracy, but slower. Larger = faster, more compression.
#
# damp_percent: float = 0.05
# Used in Hessian damping (numerical stability). Prevents division by very small numbers.
#
# damp_auto_increment: float = 0.01
# If quantization fails for a layer, damping value is automatically increased by this amount.
#
# desc_act: bool = True
# Whether to use activation ordering (descending importance) for better accuracy.
# If False, disables this reordering.
#
# act_group_aware: bool = False
# (GAR feature) Group-aware reordering. Preserves activation sensitivity per group.
# Improves accuracy for grouped quantization.
#
# static_groups: bool = False
# If True, fixes the grouping instead of dynamic grouping.
#
# sym: bool = True
# Symmetric quantization (weights centered around zero).
# If False, asymmetric (different zero-point for positive/negative).
#
# true_sequential: bool = True
# Forces strictly sequential quantization (layer by layer).
# Safer but slower.
#
# lm_head: bool = False
# Whether to quantize the final LM head (output projection).
# Usually skipped for better accuracy.
#
# quant_method: QUANT_METHOD = GPTQ
# Which quantization algorithm to use (GPTQ, GPTQv2, EoRA, QQQ, etc.).
#
# format: FORMAT = GPTQ
# Output format (GPTQ, Marlin, ExLlamaV2 kernels, etc.).
#
# mse: float = 0
# If set > 0, enables MSE minimization during quantization for extra accuracy recovery.
#
# parallel_packing: bool = True
# Enables multi-threaded packing of quantized weights for speedup.
#
# meta: Dict | None
# Extra metadata for custom configs.
#
# device: str | device | None
# Device to run quantization (cuda, cpu, mps, etc.).
#
# pack_dtype: str | dtype | None = torch.int32
# Packing dtype (int32 default, but can be int16 in some kernels).
#
# adapter: Dict | Lora | None
# Allows LoRA/EoRA adapters to be applied during or after quantization.
#
# rotation: str | None
# If rotation quantization (RQ, QRQ) is applied.
#
# is_marlin_format: bool = False
# If set, stores quantized weights in Marlin kernel format (fast inference).
#
# v2: bool = False
# Enables GPTQ v2 quantization (better accuracy, more VRAM required).
#
# v2_alpha: float = 0.25
# Extra parameter controlling Hessian approximation in GPTQv2.
#
# v2_memory_device: str = "auto"
# Controls where GPTQv2 Hessians are computed (cpu, gpu, or auto).
#
# mock_quantization: bool = False
# Runs a fake quantization pass (for debugging/testing without actually quantizing).

# %%
# increase `batch_size` to match gpu/vram specs to speed up quantization
model.quantize(calibration_dataset, batch_size=500)
# Out:
# INFO  Packing Kernel: Auto-selection: adding candidate `TritonV2QuantLinear`
# Quantizing layer 0 of 15 [0 of 15] -------------| 0:00:38 / 0:10:08 [1/16] 6.2%
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# /tmp/ipython-input-1087950935.py in <cell line: 0>()
#       1 # increase `batch_size` to match gpu/vram specs to speed up quantization
# ----> 2 model.quantize(calibration_dataset, batch_size=500)
#
# /usr/local/lib/python3.12/dist-packages/gptqmodel/models/base.py in quantize(self, calibration_dataset, calibration_dataset_concat_size, batch_size, calibration_enable_gpu_cache, tokenizer, logger_board, backend, buffered_fwd, auto_gc, adapter, adapter_calibration_dataset, calibration_data_min_length, fail_safe)
#     491         module_looper = ModuleLooper(self, processors=processors)
#     492
# --> 493         return module_looper.loop(
#     494             calibration_enable_gpu_cache=calibration_enable_gpu_cache,
#     495             buffered_fwd=buffered_fwd,
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
#     122     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/gptqmodel/looper/module_looper.py in loop(self, auto_gc, calibration_enable_gpu_cache, buffered_fwd, fail_safe, **kwargs)
#     180                 continue
#     181
# --> 182             input_cache = self.cache_inputs(layers=layers, auto_gc=auto_gc,
#     183                                             calibration_data=processor.calibration_dataset,
#     184                                             calibration_enable_gpu_cache=calibration_enable_gpu_cache,
#
# /usr/local/lib/python3.12/dist-packages/gptqmodel/looper/module_looper.py in cache_inputs(self, layers, auto_gc, calibration_data, calibration_enable_gpu_cache, use_cache)
#     123                     self.gptq_model.model.generate(**example, return_audio=False)
#     124                 else:
# --> 125                     self.gptq_model.model(**example, use_cache=use_cache)
#     126             except ValueError:
#     127                 pass
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     938         if return_dict_passed is not None:
#     939             return_dict = return_dict_passed
# --> 940         output = func(self, *args, **kwargs)
#     941         if not return_dict and not isinstance(output, tuple):
#     942             output = output.to_tuple()
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, cache_position, logits_to_keep, **kwargs)
#     457         "Hey, are you conscious? Can you talk to me?\nI'm not conscious, but I can talk to you."
#     458         ```"""
# --> 459         outputs: BaseModelOutputWithPast = self.model(
#     460             input_ids=input_ids,
#     461             attention_mask=attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#    1062                         monkey_patched_layers.append((module, original_forward))
#    1063
# -> 1064         outputs = func(self, *args, **kwargs)
#    1065         # Restore original forward methods
#    1066         for module, original_forward in monkey_patched_layers:
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, cache_position, use_cache, **kwargs)
#     366
#     367         if inputs_embeds is None:
# --> 368             inputs_embeds: torch.Tensor = self.embed_tokens(input_ids)
#     369
#     370         if use_cache and past_key_values is None:
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/sparse.py in forward(self, input)
#     190
#     191     def forward(self, input: Tensor) -> Tensor:
# --> 192         return F.embedding(
#     193             input,
#     194             self.weight,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/functional.py in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2544         # remove once script supports set_grad_enabled
#    2545         _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2546     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#    2547
#    2548
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 13.68 GiB. GPU 0 has a total capacity of 14.74 GiB of which 1.43 GiB is free. Process 13291 has 13.31 GiB memory in use. Of the allocated memory 12.31 GiB is allocated by PyTorch, and 836.73 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
model.save(quant_path)

# %%
# !pip -q install -U huggingface_hub
from huggingface_hub import notebook_login
notebook_login()

# %%
from huggingface_hub import whoami
whoami()

# %%
from huggingface_hub import upload_folder
upload_folder(
    repo_id="sunny199/Llama-3.2-1B-Instruct-gptqmodel-4bit",
    folder_path="./Llama-3.2-1B-Instruct-gptqmodel-4bit",
    commit_message="Upload GPTQ quantized LLaMA-3.2-1B model"
)

# %%
# test post-quant inference
model = GPTQModel.load(quant_path)
result = model.generate("Uncovering deep insights begins with")[0] # tokens
print(model.tokenizer.decode(result)) # string output

# %%
from datasets import load_dataset
from gptqmodel import GPTQModel, QuantizeConfig
import torch

def calculate_avg_ppl(model, tokenizer, texts, max_length=512, batch_size=8):
    """Compute average perplexity over a list of plain text strings."""
    from gptqmodel.utils.perplexity import Perplexity

    ppl = Perplexity(
        model=model,
        tokenizer=tokenizer,
        dataset_path=None,
        split=None,
        text_column=None,
    )
    # Pass list of text strings
    return ppl.calculate_from_texts(texts, max_length, batch_size)

def load_normal_model(model_id):
    return GPTQModel.load(model_id, quantize_config=None)

def load_quant_model(quant_path, device):
    return GPTQModel.load(quant_path, device=device)

def main():
    model_id = "meta-llama/Llama-3.2-1B-Instruct"
    quant_path = "Llama-3.2-1B-Instruct-gptq-4bit"
    # Load calibration / eval dataset texts
    calibration_texts = load_dataset(
        "allenai/c4",
        data_files="en/c4-train.00001-of-01024.json.gz",
        split="train"
    ).select(range(1024))["text"]

    # Subset for evaluation
    eval_texts = calibration_texts[:100]

    # Try loading quantized model if exists
    try:
        device = "cuda:0" if torch.cuda.is_available() else "cpu"
        quant_model = load_quant_model(quant_path, device=device)
        quant_exists = True
    except Exception as e:
        print("Quantized model not found or failed to load:", e)
        quant_exists = False

    # Load normal (unquantized) model
    normal_model = load_normal_model(model_id)

    # If quantized model doesn't exist, create it
    if not quant_exists:
        quant_config = QuantizeConfig(bits=4, group_size=128)
        print("Quantizing model now...")
        model = GPTQModel.load(model_id, quant_config)
        model.quantize(calibration_texts, batch_size=1)
        model.save(quant_path)
        quant_model = load_quant_model(quant_path, device=device)

    # Evaluate normal model
    print("Evaluating normal model...")
    ppl_normal = calculate_avg_ppl(normal_model, normal_model.tokenizer, eval_texts)
    print("Normal model avg PPL:", ppl_normal)

    # Evaluate quantized model
    print("Evaluating quantized model...")
    ppl_quant = calculate_avg_ppl(quant_model, quant_model.tokenizer, eval_texts)
    print("Quantized model avg PPL:", ppl_quant)

if __name__ == "__main__":
    main()

# %% [markdown]
# Allocated = currently in use.
#
# Reserved = currently held by PyTorch (in use + cached).
#
# Peak Allocated = highest ever “in use.”
#
# Peak Reserved = highest ever “held by cache.”

# %%
import torch

def measure_gpu_memory(model_loader_fn, *args, **kwargs):
    # Reset stats
    torch.cuda.reset_peak_memory_stats()
    torch.cuda.empty_cache()

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model = model_loader_fn(*args, **kwargs).to(device)

    # Do a dummy forward pass to trigger memory usage (adjust input shape as per your model)
    # For example, if it’s a language model:
    dummy_input = torch.randint(0, 100, (1, 16)).to(device)
    try:
        _ = model.generate(dummy_input)
    except Exception:
        # fallback: try forward if generate not available
        _ = model(dummy_input)

    # Collect memory stats
    mem_alloc = torch.cuda.memory_allocated(device)
    mem_reserved = torch.cuda.memory_reserved(device)
    peak_alloc = torch.cuda.max_memory_allocated(device)
    peak_reserved = torch.cuda.max_memory_reserved(device)

    print(f"Memory allocated: {mem_alloc / (1024**2):.2f} MB")
    print(f"Memory reserved:  {mem_reserved / (1024**2):.2f} MB")
    print(f"Peak alloc:       {peak_alloc / (1024**2):.2f} MB")
    print(f"Peak reserved:    {peak_reserved / (1024**2):.2f} MB")

    del model
    torch.cuda.empty_cache()


def load_normal_model(model_id):
    quantize_config=QuantizeConfig(bits=4, group_size=128)
    return GPTQModel.load(model_id, quantize_config=quantize_config)
#Example usage:
measure_gpu_memory(lambda: load_normal_model(model_id))
# measure_gpu_memory(lambda: load_quant_model(quant_path, device="cuda:0"))
# Out:
# INFO  Estimated Quantization BPW (bits per weight): 4.2875 bpw, based on [bits: 4, group_size: 128]
# Quantizing layer 0 of 15 [0 of 15] -------------| 0:10:31 / 2:48:16 [1/16] 6.2%
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# INFO  Loader: Auto dtype (native bfloat16): `torch.bfloat16`
# INFO  Model: Loaded `generation_config`: GenerationConfig {
#   "bos_token_id": 128000,
#   "do_sample": true,
#   "eos_token_id": [
#     128001,
#     128008,
#     128009
#   ],
#   "temperature": 0.6,
#   "top_p": 0.9
# }
#
# INFO  Kernel: loaded -> `[]`
# Quantizing layer 0 of 15 [0 of 15] -------------| 0:10:33 / 2:48:48 [1/16] 6.2%
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# /tmp/ipython-input-310416468.py in <cell line: 0>()
#      37     return GPTQModel.load(model_id, quantize_config=quantize_config)
#      38 #Example usage:
# ---> 39 measure_gpu_memory(lambda: load_normal_model(model_id))
#      40 # measure_gpu_memory(lambda: load_quant_model(quant_path, device="cuda:0"))
#
# /tmp/ipython-input-310416468.py in measure_gpu_memory(model_loader_fn, *args, **kwargs)
#       7
#       8     device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# ----> 9     model = model_loader_fn(*args, **kwargs).to(device)
#      10
#      11     # Do a dummy forward pass to trigger memory usage (adjust input shape as per your model)
#
# /usr/local/lib/python3.12/dist-packages/gptqmodel/models/base.py in to(self, device)
#    1109     def to(self, device: Union[str, torch.device]):
#    1110         if hasattr(self.model, "to"):
# -> 1111             self.model = self.model.to(device)
#    1112             return self
#    1113         else:
#
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py in to(self, *args, **kwargs)
#    4457                     " `dtype` by passing the correct `dtype` argument."
#    4458                 )
# -> 4459         return super().to(*args, **kwargs)
#    4460
#    4461     def half(self, *args):
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#    1367                     raise
#    1368
# -> 1369         return self._apply(convert)
#    1370
#    1371     def register_full_backward_pre_hook(
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     926         if recurse:
#     927             for module in self.children():
# --> 928                 module._apply(fn)
#     929
#     930         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     926         if recurse:
#     927             for module in self.children():
# --> 928                 module._apply(fn)
#     929
#     930         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     926         if recurse:
#     927             for module in self.children():
# --> 928                 module._apply(fn)
#     929
#     930         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     926         if recurse:
#     927             for module in self.children():
# --> 928                 module._apply(fn)
#     929
#     930         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     926         if recurse:
#     927             for module in self.children():
# --> 928                 module._apply(fn)
#     929
#     930         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     953             # `with torch.no_grad():`
#     954             with torch.no_grad():
# --> 955                 param_applied = fn(param)
#     956             p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     957
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in convert(t)
#    1353                         memory_format=convert_to_format,
#    1354                     )
# -> 1355                 return t.to(
#    1356                     device,
#    1357                     dtype if t.is_floating_point() or t.is_complex() else None,
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 32.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 22.12 MiB is free. Process 13291 has 14.72 GiB memory in use. Of the allocated memory 14.52 GiB is allocated by PyTorch, and 17.49 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
# gptqmodel is integrated into lm-eval >= v0.4.7
# !pip install lm-eval>=0.4.7

# %%
from gptqmodel import GPTQModel
from gptqmodel.utils.eval import EVAL

model_id = "ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v1"

# Use `lm-eval` as framework to evaluate the model
lm_eval_results = GPTQModel.eval(model_id, framework=EVAL.LM_EVAL, tasks=[EVAL.LM_EVAL.ARC_CHALLENGE])
# Out:
# INFO  Eval: loading using backend = `BACKEND.AUTO`
# Quantizing layer 0 of 15 [0 of 15] -------------| 0:27:34 / 7:21:04 [1/16] 6.2%from_quantized: adapter: None
# INFO  Loader: Auto dtype (native bfloat16): `torch.bfloat16`
# INFO  Estimated Quantization BPW (bits per weight): 4.85 bpw, based on [bits: 4, group_size: 32]
# INFO   Kernel: Auto-selection: adding candidate `TritonV2QuantLinear`
# INFO   Kernel: Auto-selection: adding candidate `TorchQuantLinear`
# INFO  Kernel: candidates -> `[TritonV2QuantLinear, TorchQuantLinear]`
# INFO  Kernel: selected -> `TritonV2QuantLinear`.
# Quantizing layer 0 of 15 [0 of 15] -------------| 0:27:36 / 7:21:36 [1/16] 6.2%
# WARNING:accelerate.utils.modeling:The model weights are not tied. Please use the `tie_weights` method before using the `infer_auto_device` function.
# INFO  Format: Converting `checkpoint_format` from `FORMAT.GPTQ` to internal `FORMAT.GPTQ_V2`.
# INFO  Format: Conversion complete: 0.012720584869384766s
# INFO   Kernel: Auto-selection: adding candidate `TritonV2QuantLinear`
# INFO  Model: Loaded `generation_config`: GenerationConfig {
#   "bos_token_id": 128000,
#   "eos_token_id": [
#     128001,
#     128008,
#     128009
#   ]
# }
#
# INFO  Model: `generation_config.json` not found. Skipped checking.
# INFO  Kernel: loaded -> `[TritonV2QuantLinear]`
# Quantizing layer 0 of 15 [0 of 15] -------------| 0:27:44 / 7:23:44 [1/16] 6.2%
# WARNING:lm_eval.models.huggingface:`pretrained` model kwarg is not of type `str`. Many other model arguments may be ignored. Please do not launch via accelerate or use `parallelize=True` if passing an existing model this way.
# WARNING:lm_eval.models.huggingface:Passed an already-initialized model through `pretrained`, assuming single-process call to evaluate() or custom distributed integration
# INFO  LM-EVAL: `gen_kwargs` = `do_sample=False,temperature=1.0,top_k=50,top_p=1.0`
# INFO  LM-EVAL: `apply_chat_template` = `False`
# Quantizing layer 0 of 15 [0 of 15] -------------| 0:27:44 / 7:23:44 [1/16] 6.2%
# WARNING:lm_eval.evaluator:pretrained=ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v1 appears to be an instruct or chat variant but chat template is not
#         applied. Recommend setting `apply_chat_template` (optionally `fewshot_as_multiturn`).
# WARNING:lm_eval.evaluator:generation_kwargs: {'do_sample': False, 'temperature': 1.0, 'top_k': 50, 'top_p': 1.0} specified through cli, these settings will update set parameters in yaml tasks. Ensure 'do_sample=True' for non-greedy decoding!
# README.md: 0.00B [00:00, ?B/s]
# ARC-Challenge/train-00000-of-00001.parqu(…):   0%|          | 0.00/190k [00:00<?, ?B/s]
# ARC-Challenge/test-00000-of-00001.parque(…):   0%|          | 0.00/204k [00:00<?, ?B/s]
# ARC-Challenge/validation-00000-of-00001.(…):   0%|          | 0.00/55.7k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1119 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1172 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/299 [00:00<?, ? examples/s]
# 100%|██████████| 1172/1172 [00:01<00:00, 1031.46it/s]
# Running loglikelihood requests: 100%|██████████| 4687/4687 [07:08<00:00, 10.93it/s]
# --------lm_eval Eval Result---------
# |    Tasks    |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |-------------|------:|------|-----:|--------|---|-----:|---|-----:|
# |arc_challenge|      1|none  |     0|acc     |↑  |0.2799|±  |0.0131|
# |             |       |none  |     0|acc_norm|↑  |0.3063|±  |0.0135|
#
# --------lm_eval Result End---------

# %% [markdown]
# These are the evaluation metrics for the quantized model on the ARC Challenge task.
#
# acc is accuracy, acc_norm is normalized accuracy, etc.
#
# 0.2799 means ~27.99% accuracy, with a standard error ±0.0131.
#
# The evaluation harness printed the result table.

# %% [markdown]
# ### Bits & Bytes / Quantization Context
#
# bitsandbytes is a library that implements efficient quantized operations (4-bit, 8-bit) for matrices / linear layers, especially useful for large models.
#
# The transformers library supports integration with bitsandbytes via a BitsAndBytesConfig class. That config tells from_pretrained how to load model weights in lower precision (4-bit or 8-bit) rather than default high precision.
#
# This integration is meant for inference (or adapter training) rather than full training from scratch. It reduces VRAM / memory footprint a lot, and you can still generate text.

# %%
# !pip install transformers accelerate
# !pip install -U bitsandbytese
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

model_id = "meta-llama/Llama-3.1-8B-Instruct"   # example HF model
bnb = BitsAndBytesConfig(load_in_4bit=True)      # or load_in_8bit=True
tok = AutoTokenizer.from_pretrained(model_id, use_fast=True)
model = AutoModelForCausalLM.from_pretrained(
    model_id, quantization_config=bnb, device_map="auto"
)

inputs = tok("Explain GPTQ vs AWQ simply.", return_tensors="pt").to(model.device)
out = model.generate(**inputs, max_new_tokens=80)
print(tok.decode(out[0], skip_special_tokens=True))

# %% [markdown]
# ### ExLlama
#
# ExLlama is a Python/C++/CUDA implementation tailored for Llama (and Llama-style) models, working especially with 4-bit GPTQ weights.
#
# It provides optimized kernels (linear layers, quantized operators) for inference, to accelerate generation speed and reduce memory overhead.
#
# ExLlamaV2 adds more features: e.g. EXL2 format (a flexible quantization format), better kernel optimizations, dynamic batching, new generation strategies.
#
# ExLlama is often integrated into quantization+inference pipelines — e.g. Transformers’ GPTQ support may allow using ExLlama kernels by specifying certain config flags.

# %%
# !pip install exllamav2
from exllamav2 import ExLlamaV2, ExLlamaV2Config, ExLlamaV2Tokenizer, ExLlamaV2Generator
from exllamav2 import ExLlamaV2, ExLlamaV2Config, ExLlamaV2Tokenizer, ExLlamaV2Generator
# Download a GPTQ/EXL2 model first or point to HF snapshot dir with config + shards
# Example assumes local path `./model` with GPTQ weights (ex: TheBloke GPTQ)
model_path = "/content/model"  # put your GPTQ model dir here

cfg = ExLlamaV2Config()
cfg.model_dir = model_path
model = ExLlamaV2(cfg)
tok = ExLlamaV2Tokenizer(model_path)
gen = ExLlamaV2Generator(model, tok)

print(gen.generate_simple("Explain GPTQ vs AWQ simply.", max_new_tokens=80))
